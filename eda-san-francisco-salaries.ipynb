# %%
# Nabil FATTOUCH 
# Date : 31/08/2021 
# Data source: "/kaggle/input/salaries/Salaries.csv"

# %%
# Answer questions asked by  client who is a  human resources   and management control department
# The client located in San Francisco, wants to know its data. 
# This department asks a set of questions to evaluate the salaries attributed to their employees which are the following:





# variable target :  TotalPayBenefits

# Analysis of the data form :

# Rows and columns : (148654, 13)
# Analysis of NaN 
 # • Elimination of useless columns (Ratio Sum NaN/ Total ( shape ! ) < 70 %
 # • Many NaN for columns "Notes"and "Statuts"(half of the variables > 70% of NaN)
 
# In-depth analysis : 
 # • Visualization of the target 
 # • Average 
 # • The highest salary in the company, the name of the person and the position held?
 # • Positions have the lowest salaries and for which people in the company ?
 # •The number of job titles were represented by only one person in 2014
 # • Top 07 persons works the most overtime ? 
 # • Relationship between the position held and the amount of overtime worked?
 # • Rbetween OvertimePay and TotalPayBenefits?
# Exploratory of others  variables :
 # • The highest amount of OvertimePay in the dataset 
 # • The number of people having the word captain in their job title
 # • Top-07 jobs in which there are majority of the people ( in %) ?
 # • The average ( mean) TotalPayBenefit of all employees per year ( 2011-2014)

# %%
## Import packages 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_row', 111)              # If we want to display the result in full 
pd.set_option('display.max_column', 111)

# %%
filename = "/kaggle/input/salaries/Salaries.csv"
df = pd.read_csv(filename)
# Out:
# /opt/conda/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3170: DtypeWarning: Columns (3,4,5,6,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# 1  155966.02   245131.88  137811.38      NaN  538909.28         538909.28
# 2  212739.13   106088.18    16452.6      NaN  335279.91         335279.91
# 3    77916.0    56120.71   198306.9      NaN  332343.61         332343.61
# 4   134401.6      9737.0  182234.59      NaN  326373.19         326373.19
#
#    Year  Notes         Agency Status
# 0  2011    NaN  San Francisco    NaN
# 1  2011    NaN  San Francisco    NaN
# 2  2011    NaN  San Francisco    NaN
# 3  2011    NaN  San Francisco    NaN
# 4  2011    NaN  San Francisco    NaN

# %%
df1= df.copy()
df1.head(7)
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5   6     DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 6   7          ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# 1  155966.02   245131.88  137811.38      NaN  538909.28         538909.28
# 2  212739.13   106088.18    16452.6      NaN  335279.91         335279.91
# 3    77916.0    56120.71   198306.9      NaN  332343.61         332343.61
# 4   134401.6      9737.0  182234.59      NaN  326373.19         326373.19
# 5   118602.0      8601.0  189082.74      NaN  316285.74         316285.74
# 6   92492.01     89062.9  134426.14      NaN  315981.05         315981.05
#
#    Year  Notes         Agency Status
# 0  2011    NaN  San Francisco    NaN
# 1  2011    NaN  San Francisco    NaN
# 2  2011    NaN  San Francisco    NaN
# 3  2011    NaN  San Francisco    NaN
# 4  2011    NaN  San Francisco    NaN
# 5  2011    NaN  San Francisco    NaN
# 6  2011    NaN  San Francisco    NaN

# %%
pd.show_versions()
# Out:
# INSTALLED VERSIONS
# ------------------
# commit           : 2cb96529396d93b46abab7bbc73a208e708c642e
# python           : 3.7.10.final.0
# python-bits      : 64
# OS               : Linux
# OS-release       : 5.4.120+
# Version          : #1 SMP Wed Aug 18 10:20:32 PDT 2021
# machine          : x86_64
# processor        : x86_64
# byteorder        : little
# LC_ALL           : C.UTF-8
# LANG             : C.UTF-8
# LOCALE           : en_US.UTF-8
#
# pandas           : 1.2.4
# numpy            : 1.19.5
# pytz             : 2021.1
# dateutil         : 2.8.1
# pip              : 21.1.2
# setuptools       : 49.6.0.post20210108
# Cython           : 0.29.23
# pytest           : 6.2.4
# hypothesis       : 6.14.1
# sphinx           : None
# blosc            : None
# feather          : 0.4.1
# xlsxwriter       : None
# lxml.etree       : 4.6.3
# html5lib         : 1.1
# pymysql          : None
# psycopg2         : None
# jinja2           : 3.0.1
# IPython          : 7.24.1
# pandas_datareader: 0.9.0
# bs4              : 4.9.3
# bottleneck       : 1.3.2
# fsspec           : 2021.06.1
# fastparquet      : None
# gcsfs            : 2021.06.0
# matplotlib       : 3.4.2
# numexpr          : 2.7.3
# odfpy            : None
# openpyxl         : None
# pandas_gbq       : None
# pyarrow          : 4.0.0
# pyxlsb           : None
# s3fs             : 2021.06.1
# scipy            : 1.6.3
# sqlalchemy       : 1.4.18
# tables           : 3.6.1
# tabulate         : 0.8.9
# xarray           : 0.18.2
# xlrd             : None
# xlwt             : None
# numba            : 0.53.1

# %% [markdown]
# # Analysis of the data form

# %%
                                      # number of columns and rows 

df1.shape
# Out:
# (148654, 13)

# %%
df1.columns                            # Columns names
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
print("Number of rows in dataset: ",df1.shape[0])
print("Number of columns in dataset: ",df1.shape[1])
# Out:
# Number of rows in dataset:  148654
# Number of columns in dataset:  13

# %%
#df1.dtypes()
df1.dtypes.value_counts()              #  Data types
# Out:
# object     8
# float64    3
# int64      2
# dtype: int64

# %%
df1.dtypes.value_counts().plot.pie()   # Data types visualization
# Out:
# <AxesSubplot:ylabel='None'>

# %%
df1.isnull().sum(axis=0)                # Checking the NaN  in the dataset
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                605
# OvertimePay              0
# OtherPay                 0
# Benefits             36159
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              110535
# dtype: int64

# %%
df1.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# 1  155966.02   245131.88  137811.38      NaN  538909.28         538909.28
# 2  212739.13   106088.18    16452.6      NaN  335279.91         335279.91
# 3    77916.0    56120.71   198306.9      NaN  332343.61         332343.61
# 4   134401.6      9737.0  182234.59      NaN  326373.19         326373.19
#
#    Year  Notes         Agency Status
# 0  2011    NaN  San Francisco    NaN
# 1  2011    NaN  San Francisco    NaN
# 2  2011    NaN  San Francisco    NaN
# 3  2011    NaN  San Francisco    NaN
# 4  2011    NaN  San Francisco    NaN

# %% [markdown]
# # Analysis of NaN :

# %%
                                      # Visualization of NaN 

plt.figure(figsize=(20,10))           # To create a figure of dimensions 20, 10 
sns.heatmap(df1.isna(), cbar=False)    # cbar = False to eliminate the colored bar
# Out:
# <AxesSubplot:>

# %%
df.isna().sum()
# Out:
# /opt/conda/lib/python3.7/site-packages/IPython/core/displayhook.py:276: UserWarning: Output cache limit (currently 1000 entries) hit.
# Flushing oldest 200 entries.
#   'Flushing oldest {cull_count} entries.'.format(sz=sz, cull_count=cull_count))
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                605
# OvertimePay              0
# OtherPay                 0
# Benefits             36159
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              110535
# dtype: int64

# %%
(df1.isna().sum()/df1.shape[0]).sort_values( ascending = True)
# Out:
# Id                  0.000000
# EmployeeName        0.000000
# JobTitle            0.000000
# OvertimePay         0.000000
# OtherPay            0.000000
# TotalPay            0.000000
# TotalPayBenefits    0.000000
# Year                0.000000
# Agency              0.000000
# BasePay             0.004070
# Benefits            0.243243
# Status              0.743572
# Notes               1.000000
# dtype: float64

# %%
# • Elimination of useless columns (Ratio Sum NaN/ Total ( shape ! ) > 70 %
 # • Many NaN for columns "Notes"and "Statuts"(more than half of the variables > 70% of NaN)

 ## sns.heatmap(df1.isna() )

# %%
df2= df1[df1.columns[df1.isna().sum()/df1.shape[0] < 0.7] ]
    
    # 1/ df.isna().sum()/df.shape[0] >0.7     2/df.columns[df.isna().sum()/df.shape[0] > 0.7]

    # What we do here is boolean indexing, i.e. I take the table of columns df.columns[df.isna().sum()/df.shape[0] < 0.7] 
    # and I inject it in our new dataframe df and we save

# %%
df2.head(7)
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5   6     DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 6   7          ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# 1  155966.02   245131.88  137811.38      NaN  538909.28         538909.28
# 2  212739.13   106088.18    16452.6      NaN  335279.91         335279.91
# 3    77916.0    56120.71   198306.9      NaN  332343.61         332343.61
# 4   134401.6      9737.0  182234.59      NaN  326373.19         326373.19
# 5   118602.0      8601.0  189082.74      NaN  316285.74         316285.74
# 6   92492.01     89062.9  134426.14      NaN  315981.05         315981.05
#
#    Year         Agency
# 0  2011  San Francisco
# 1  2011  San Francisco
# 2  2011  San Francisco
# 3  2011  San Francisco
# 4  2011  San Francisco
# 5  2011  San Francisco
# 6  2011  San Francisco

# %%
# elimination of rows
# In the data frame above, it is visible that there are some rows in which no values is entered, 
# which is equal to NaN . So we need to delete these rows.

df2 = df2[df2['EmployeeName'] != 'Not provided']
df2 = df2[df2['JobTitle'] != 'Not provided']
df2.reset_index(inplace = True, drop = True)
df2
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148645  148646   Carolyn A Wilson
# 148646  148648     Joann Anderson
# 148647  148649        Leon Walker
# 148648  148650      Roy I Tillery
# 148649  148654          Joe Lopez
#
#                                               JobTitle    BasePay OvertimePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18         0.0
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02   245131.88
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13   106088.18
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC    77916.0    56120.71
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)   134401.6      9737.0
# ...                                                ...        ...         ...
# 148645                       Human Services Technician       0.00        0.00
# 148646                     Communications Dispatcher 2       0.00        0.00
# 148647                                       Custodian       0.00        0.00
# 148648                                       Custodian       0.00        0.00
# 148649                      Counselor, Log Cabin Ranch       0.00        0.00
#
#          OtherPay Benefits   TotalPay  TotalPayBenefits  Year         Agency
# 0       400184.25      NaN  567595.43         567595.43  2011  San Francisco
# 1       137811.38      NaN  538909.28         538909.28  2011  San Francisco
# 2         16452.6      NaN  335279.91         335279.91  2011  San Francisco
# 3        198306.9      NaN  332343.61         332343.61  2011  San Francisco
# 4       182234.59      NaN  326373.19         326373.19  2011  San Francisco
# ...           ...      ...        ...               ...   ...            ...
# 148645       0.00     0.00       0.00              0.00  2014  San Francisco
# 148646       0.00     0.00       0.00              0.00  2014  San Francisco
# 148647       0.00     0.00       0.00              0.00  2014  San Francisco
# 148648       0.00     0.00       0.00              0.00  2014  San Francisco
# 148649    -618.13     0.00    -618.13           -618.13  2014  San Francisco
#
# [148650 rows x 11 columns]

# %%
                                     # Unique values in dataset
    
print('Number of unique values in Job-Title column are:',df['JobTitle'].nunique())
print('Number of unique values in Agency column are:',df['Agency'].nunique())
print('Number of unique values in Year column are:',df['Year'].nunique())
# Out:
# Number of unique values in Job-Title column are: 2159
# Number of unique values in Agency column are: 1
# Number of unique values in Year column are: 4

# %%
print("Job-Title:",df['JobTitle'].unique())

print("Agency:",df['Agency'].unique())
print("Year:",df['Year'].unique())
# Out:
# Job-Title: ['GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY'
#  'CAPTAIN III (POLICE DEPARTMENT)' 'WIRE ROPE CABLE MAINTENANCE MECHANIC'
#  ... 'Conversion' 'Cashier 3' 'Not provided']
# Agency: ['San Francisco']
# Year: [2011 2012 2013 2014]

# %% [markdown]
# # Visualization of the target

# %%
# Examination of the Target column : TotalPayBenefits

# %%
df2['TotalPayBenefits'].value_counts()  # if you want to display the result in %. , value_counts(normalize=True)
# Out:
# 7959.18      263
# 123290.70     56
# 132242.50     49
# 26058.70      43
# 105489.00     42
#             ...
# 45807.58       1
# 161456.05      1
# 210347.57      1
# 135674.19      1
# 112929.93      1
# Name: TotalPayBenefits, Length: 142098, dtype: int64

# %%
df2['TotalPayBenefits'].value_counts(normalize=True)
# Out:
# 7959.18      0.001769
# 123290.70    0.000377
# 132242.50    0.000330
# 26058.70     0.000289
# 105489.00    0.000283
#                ...
# 45807.58     0.000007
# 161456.05    0.000007
# 210347.57    0.000007
# 135674.19    0.000007
# 112929.93    0.000007
# Name: TotalPayBenefits, Length: 142098, dtype: float64

# %%
# meaning of variables (continuous!) ( Histogram of continuous variables )

for col in df2.select_dtypes('float'): print(col)  
                                                 # We check what we have as columns 
                                                 # then we will create histograms,
                                                 # we will observe the distribution, 
                                                 # the distribution of data for each of its columns. 
                                                 # For that, we can use Matplotlib or seaborn
# Out:
# TotalPay
# TotalPayBenefits

# %%
for col in df2.select_dtypes('float'): 
                                                 # displot: a distribution curve and we will pass through it
                                                 # each time the column (variable) of our df 
    plt.figure()
    sns.displot(df[col])          
                                                
                                                 # and they appear to have a standard deviation = 1. 
                                                 # This immediately suggests that these data 
                                                 # have been standardized 
                                               
                                                 #  A perfect positive relationship between the two variables.

# %%
df2[['TotalPay', 'TotalPayBenefits']].corr()
# Out:
#                   TotalPay  TotalPayBenefits
# TotalPay          1.000000          0.977312
# TotalPayBenefits  0.977312          1.000000

# %%
df2[['OvertimePay','TotalPayBenefits']].corr()
# Out:
#                   TotalPayBenefits
# TotalPayBenefits               1.0

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148650 entries, 0 to 148649
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148650 non-null  int64
#  1   EmployeeName      148650 non-null  object
#  2   JobTitle          148650 non-null  object
#  3   BasePay           148045 non-null  object
#  4   OvertimePay       148650 non-null  object
#  5   OtherPay          148650 non-null  object
#  6   Benefits          112491 non-null  object
#  7   TotalPay          148650 non-null  float64
#  8   TotalPayBenefits  148650 non-null  float64
#  9   Year              148650 non-null  int64
#  10  Agency            148650 non-null  object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 12.5+ MB

# %%
# The highest salary in the company, the name of the Employee and the JobTitle?

df2[df2['TotalPayBenefits'] == df2['TotalPayBenefits'].max()]
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
#
#    Year         Agency
# 0  2011  San Francisco

# %%
df2[df2['TotalPayBenefits'] == df2['TotalPayBenefits'].max()]['EmployeeName']
# Out:
# 0    NATHANIEL FORD
# Name: EmployeeName, dtype: object

# %%
df2[df2['TotalPayBenefits'] == df2['TotalPayBenefits'].max()]['TotalPayBenefits']
# Out:
# 0    567595.43
# Name: TotalPayBenefits, dtype: float64

# %%
df2['TotalPayBenefits'].value_counts().head(15)
# Out:
# 7959.18      263
# 123290.70     56
# 132242.50     49
# 26058.70      43
# 105489.00     42
# 2645.45       37
# 25659.10      36
# 69237.18      36
# 33739.71      34
# 64625.68      34
# 2610.54       30
# 92865.72      28
# 0.00          26
# 53539.40      24
# 57630.60      23
# Name: TotalPayBenefits, dtype: int64

# %%
df2['Year']== 2014
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 148645     True
# 148646     True
# 148647     True
# 148648     True
# 148649     True
# Name: Year, Length: 148650, dtype: bool

# %%
df2[df2['Year']== 2014]['JobTitle']
# Out:
# 110531                 Deputy Chief 3
# 110532              Asst Med Examiner
# 110533       Chief Investment Officer
# 110534                Chief of Police
# 110535         Chief, Fire Department
#                      ...
# 148645      Human Services Technician
# 148646    Communications Dispatcher 2
# 148647                      Custodian
# 148648                      Custodian
# 148649     Counselor, Log Cabin Ranch
# Name: JobTitle, Length: 38119, dtype: object

# %%
df2[df2['Year']== 2014]['JobTitle'].value_counts()
# Out:
# Transit Operator                2479
# Special Nurse                   1478
# Registered Nurse                1234
# Public Svc Aide-Public Works     916
# Firefighter                      815
#                                 ...
# Carpenter Supervisor 2             1
# Chf Victim/Witness Invstgtor       1
# Asst Director, Juvenile Hall       1
# Animal Care Asst Supv              1
# Senior Claims Investigator         1
# Name: JobTitle, Length: 996, dtype: int64

# %%
(df2[df2['Year']== 2014]['JobTitle'].value_counts() ==1).sum()
# Out:
# 175

# %%
df2['TotalPayBenefits'].mean()
# Out:
# 93695.07596912362

# %% [markdown]
# ## The highest amount of OvertimePay in the dataset

# %%
df2['EmployeeName']== 'PATRICK GARDNER'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4          True
#           ...
# 148645    False
# 148646    False
# 148647    False
# 148648    False
# 148649    False
# Name: EmployeeName, Length: 148650, dtype: bool

# %%
df2[df1['EmployeeName']=='GARY JIMENEZ']['JobTitle']
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# 1    CAPTAIN III (POLICE DEPARTMENT)
# Name: JobTitle, dtype: object

# %%
df2[df2['EmployeeName']=='GARY JIMENEZ']['TotalPayBenefits']
# Out:
# 1    538909.28
# Name: TotalPayBenefits, dtype: float64

# %%
## the average ( mean) TotalPayBenefits of all employees per year ( 2011-2014)

# %%
df2_by_year=df2.groupby('Year').mean()['TotalPayBenefits']
df2_by_year
# Out:
# Year
# 2011     71744.103871
# 2012    100553.229232
# 2013    101440.519714
# 2014    100261.438668
# Name: TotalPayBenefits, dtype: float64

# %%
ax = df2_by_year.plot(kind='bar', title ="Average ( mean) TotalPayBenefits of all employees per year", figsize=(16, 10), legend=True, fontsize=10)
ax.set_xlabel("TotalPayBenefits", fontsize=12)
ax.set_ylabel("Year", fontsize=12)
plt.show()

# %% [markdown]
# ## The top 07  most popular jobs

# %%
df2['JobTitle'].value_counts()

# %%
df3= df2['JobTitle'].value_counts().head(7)
df3

# %%
ax = df3.plot(kind='bar', title ="The top 07  most popular jobs", figsize=(15, 10), legend=True, fontsize=12)
ax.set_xlabel("JobTitle", fontsize=12)
ax.set_ylabel("Year", fontsize=12)
plt.show()

# %% [markdown]
# ## The number of job titles were represented by only one person in 2014

# %%
df2['Year']== 2014

# %%
df2[df2['Year']== 2014]['JobTitle']

# %%
df2[df2['Year']== 2014]['JobTitle'].value_counts()

# %%
(df2[df2['Year']== 2014]['JobTitle'].value_counts() ==1).sum()

# %% [markdown]
# ## The number of people having the word captain in their job title

# %%
def captain(string):
    if 'captain' in (string.lower()):
        return True
    else:
        return False

# %%
 captain('CAPTAIN SERVICE') # test of function

# %%
(df2['JobTitle'].apply(lambda x: captain(x)))

# %%
(df2['JobTitle'].apply(lambda x: captain(x))).sum()
